# %% [markdown]
# <a href="https://colab.research.google.com/github/fatemeh-ebadi/Deep-learning-course/blob/main/Copy_of_first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# REMEMBER to import the library into your notebook
import torch
x=3
torch.tensor (x) # function
# Out:
# tensor(3)

# %%
# REMEMBER to import the library into your notebook
import torch
x=3
# Let's create our first scalar pytorch tensors with some default values:
my_tensor=torch.tensor(x)
print(my_tensor)
# Out:
# tensor(3)

# %%
import torch
# Scalar (rank 0)
scalar= torch.tensor(5)
# Let's see rank & shape
print("scalar:", scalar)
print("Rank:", scalar.ndim) #For a scalar tensor, the rank is 0,
# Out:
# scalar: tensor(5)
# Rank: 0

# %% [markdown]
# # New Section
